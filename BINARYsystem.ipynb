# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import pi,gravitational_constant
import scipy as sci
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import animation
from scipy.integrate import odeint
import progressbar
from IPython.display import clear_output

# %%
import binarySYSTEM as BS

# %%
m1=1.1 #SiriusA
m2=0.907 #Sirius B

e=0.5178
ascNODE=204.85*np.pi/180
periastron=231.65*np.pi/180
distance=4.37*63241
a=distance*17.57*np.pi/(180*3600) #in AU
i=79.205*np.pi/180
P=79.91

# %%
sysOBJ=BS.BinarySystem(m1,m2,a,e,theta=periastron+ascNODE)

# %%
sysOBJ.BINARYplotter(1,frame='cm')

# %%
sysOBJ.radVELcurvePlot(i,periastron,ascNODE)
